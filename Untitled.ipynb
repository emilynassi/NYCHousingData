# %%
#Dependencies
import pandas as pd 
from matplotlib import pyplot as plt
import numpy as np 
import seaborn as sns 
import requests as req
import random 

from requirements import CreateDataframe 

dataframe = CreateDataframe()

dataframe.head()
# Out:
#      BOROUGH               NEIGHBORHOOD BUILDING CLASS AT PRESENT  \
# 0  Manhattan  INWOOD                                           A5
# 1  Manhattan  WASHINGTON HEIGHTS LOWER                         A9
# 2  Manhattan  HARLEM-EAST                                      A5
# 3  Manhattan  HARLEM-EAST                                      A5
# 4  Manhattan  HARLEM-EAST                                      A9
#
#                                      ADDRESS APARTMENT NUMBER  ZIP CODE  \
# 0  49 MARBLE HILL AVENUE                                          10463
# 1  16 SYLVAN TERRACE                                              10032
# 2  104 EAST 101 STREET                                            10029
# 3  104 EAST 101ST STREET                                          10029
# 4  101B EAST 97TH STREET                                          10029
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS TOTAL UNITS LAND SQUARE FEET  \
# 0                1.0                 0           1             1219
# 1                1.0                 0           1              673
# 2                1.0                 0           1             1607
# 3                1.0                 0           1             1607
# 4                1.0                 0           1              847
#
#   GROSS SQUARE FEET  YEAR BUILT BUILDING CLASS AT TIME OF SALE   SALE PRICE   \
# 0              1224        1920                             A5      635000.0
# 1              1425        1899                             A9     1560000.0
# 2              1466        1890                             A5           NaN
# 3              1466        1890                             A5           NaN
# 4              1472        1925                             A9           NaN
#
#   SALE DATE  BUILDING CLASS                                   CATEGORY  \
# 0   8/18/17               1   ONE FAMILY DWELLINGS
# 1   9/28/17               1   ONE FAMILY DWELLINGS
# 2   3/31/17               1   ONE FAMILY DWELLINGS
# 3    2/4/17               1   ONE FAMILY DWELLINGS
# 4    3/7/17               1   ONE FAMILY DWELLINGS
#
#           sale_type Price Category
# 0  Residential Sale    $500K-$750K
# 1  Residential Sale      $1.5M-$2M
# 2  Residential Sale            NaN
# 3  Residential Sale            NaN
# 4  Residential Sale            NaN
